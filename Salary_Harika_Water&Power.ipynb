# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Output/filtered_dataset.csv', low_memory=False)
df
# Out:
#         Row ID  Year       Department Title  Payroll Department Record Number  \
# 0       162645  2015  Water And Power (DWP)                 NaN    2130375699
# 1       123059  2015            Fire (LAFD)              3001.0    1079101020
# 2       103259  2014  Water And Power (DWP)                 NaN    3818541918
# 3        65132  2014            Fire (LAFD)              3001.0    3000652402
# 4        65133  2014            Fire (LAFD)              3001.0    3828116389
# ...        ...   ...                    ...                 ...           ...
# 205728  160650  2015   Recreation And Parks              7903.0    1946441534
# 205729  267937  2016   Recreation And Parks              7903.0    2777667565
# 205730  268734  2016   Recreation And Parks              7903.0     511191671
# 205731  268972  2016   Recreation And Parks              7903.0    1869873817
# 205732  118121  2015        Airports (LAWA)               101.0    4040358985
#
# ...

# %%
grouped_df = df.groupby('Department Title')
grouped_df.nunique()
# Out:
#                            Row ID  Year  Payroll Department  Record Number  \
# Department Title
# Airports (LAWA)             18057     4                   1           4311
# Fire (LAFD)                 18048     4                   3           4172
# Police (LAPD)               66049     4                   3          14828
# Public Works - Sanitation   14738     4                  39           3667
# Recreation And Parks        35340     4                   6           9871
# Water And Power (DWP)       53501     4                   0          13022
#
#                            Job Class Title  Employment Type  \
# Department Title
# Airports (LAWA)                        327                2
# Fire (LAFD)                            125                2
# Police (LAPD)                          197                3
# Public Works - Sanitation              223                2
# Recreation And Parks                   229                3
# ...

# %%
Water_Power_df = df[df['Department Title']=='Water And Power (DWP)']
Water_Power_df
# Out:
#         Row ID  Year       Department Title  Payroll Department Record Number  \
# 0       162645  2015  Water And Power (DWP)                 NaN    2130375699
# 2       103259  2014  Water And Power (DWP)                 NaN    3818541918
# 5       162646  2015  Water And Power (DWP)                 NaN    3818541918
# 10      103260  2014  Water And Power (DWP)                 NaN    4248318798
# 12      162647  2015  Water And Power (DWP)                 NaN    2758813101
# ...        ...   ...                    ...                 ...           ...
# 205519  113975  2014  Water And Power (DWP)                 NaN    4250514547
# 205588  173705  2015  Water And Power (DWP)                 NaN    3840852980
# 205644   57050  2013  Water And Power (DWP)                 NaN    4206373588
# 205679  276492  2016  Water And Power (DWP)                 NaN     855091199
# 205680  219778  2016  Water And Power (DWP)                 NaN     855091199
#
# ...

# %%
# Water_Power_df.isna().sum()

# %%
Water_Power_df.plot(x="Year", y=["Projected Annual Salary", "Total Payments"], kind="bar")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-bb1cfb6ad98a> in <module>
# ----> 1 Water_Power_df.plot(x="Year", y=["Projected Annual Salary", "Total Payments"], kind="bar")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
# year_projsal = Water_Power_df[['Year'],['Projected Annual Salary']]

# year_projsal.plot(kind='bar')

# # plt.bar(Water_Power_df['Year'], Water_Power_df['Projected Annual Salary'])
# # plt.bar(Water_Power_df['Year'], Water_Power_df['Total Payments'])
