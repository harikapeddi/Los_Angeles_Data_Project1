# %%
#importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)

# %%
#importing the CSV file 
clean_data= pd.read_csv('Output/filtered_dataset.csv')
clean_data.head()
# Out:
# C:\Users\squiros\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Row ID  Year       Department Title  Payroll Department Record Number  \
# 0  162645  2015  Water And Power (DWP)                 NaN    2130375699
# 1  123059  2015            Fire (LAFD)              3001.0    1079101020
# 2  103259  2014  Water And Power (DWP)                 NaN    3818541918
# 3   65132  2014            Fire (LAFD)              3001.0    3000652402
# 4   65133  2014            Fire (LAFD)              3001.0    3828116389
#
#                                    Job Class Title Employment Type  \
# 0      Electrical Distribution Mechanic Supervisor       Full Time
# 1                      Engineer of Fire Department       Full Time
# 2  Transmission & Distribution District Supervisor       Full Time
# ...

# %%
#grouping by department title = Airports (LAWA)
#airport_data = clean_data.loc[(clean_data['Department Title']=="Airports (LAWA)")
#airport_data
airport_data = clean_data.loc[(clean_data['Department Title']=="Airports (LAWA)") & (clean_data['Year']!=2016) ]
#airport_data = clean_data.loc[(clean_data['Year']!=2016)]
airport_data.sort_values(by= ['Hourly or Event Rate'], ascending=False)
# Out:
#         Row ID  Year Department Title  Payroll Department Record Number  \
# 9449    114540  2015  Airports (LAWA)               101.0    3303590766
# 33      114378  2015  Airports (LAWA)               101.0    2525431620
# 161      57430  2014  Airports (LAWA)               101.0    2525431620
# 283         48  2013  Airports (LAWA)               101.0    2525431620
# 174     114379  2015  Airports (LAWA)               101.0      32381316
# ...        ...   ...              ...                 ...           ...
# 183699    3569  2013  Airports (LAWA)               101.0    1051775753
# 191443    3609  2013  Airports (LAWA)               101.0    3513800404
# 149286   60736  2014  Airports (LAWA)               101.0    2145485481
# 184530    3576  2013  Airports (LAWA)               101.0    1532556761
# 175958    3526  2013  Airports (LAWA)               101.0    2025213404
#
#                            Job Class Title Employment Type  \
# ...

# %%
len(airport_data['Job Class Title'].unique()),airport_data['Job Class Title'].unique()
# Out:
# (316,
#  array(['Assistant General Manager Airports',
#         'Deputy General Manager Airports/1',
#         'Deputy General Manager Airports I', 'Chief Management Analyst',
#         'Deputy General Manager Airports/2', 'Airport Police Sergeant II',
#         'Airport Manager III', 'Airport Police Officer III',
#         'Director of Airport Safety Services',
#         'Director of Airports Operations',
#         'Deputy General Manager Airports II', 'Airport Police Lieutenant',
#         'Senior Airport Safety Officer',
#         'Construction and Maintenance Supervisor II',
#         'Principal Construction Inspector', 'Chief Financial Officer',
#         'Executive Assistant Airports', 'Airport Police Sergeant I',
#         'Heavy Duty Equipment Mechanic',
#         'Airports Maintenance Superintendent', 'Airport Police Chief',
#         'Assistant Airport Police Chief', 'Chief Airports Engineer II',
#         'Systems Programmer III', 'Airport Safety Officer II',
# ...

# %%
len(airport_data['Job Class'].unique()),airport_data['Job Class'].unique()
# Out:
# (225,
#  array([ 160,  162, 9182,  163, 3226, 7260, 3225, 9306, 9304, 3227, 3203,
#         3127, 7297, 9230, 9186, 3743, 3331, 3232, 3234, 7274, 1455, 3202,
#         9424, 1964, 1409, 3336, 7294, 7258, 3863, 3181, 3184, 7268, 7270,
#         3446, 7257, 3200, 9422, 1552, 3228, 7291, 7945, 3864, 1530, 1610,
#         9184, 3865, 1557, 1593, 7296, 3843, 3585,  161, 7610, 1788, 3443,
#         7286, 3156, 5925, 3844, 3346, 5927, 3584, 9171, 7607, 7614, 9167,
#         3866, 1404, 1470, 1596, 1714, 3781, 7640, 7304, 3205, 3421, 3869,
#         3745, 1555, 3525, 1597, 9262, 1702, 7926, 1835, 9485, 7320, 3686,
#         1431, 3711, 7554, 7237, 3638, 7283, 1625, 7246, 5923, 3347, 3157,
#         3444, 1117, 3177, 7935, 2485, 7957, 2330, 3115, 3589, 3774, 3588,
#         3689, 3345, 7525, 7280, 1461, 7214, 3716, 1525, 7642, 3433, 1961,
#         1852, 7310, 2500, 1549, 9170, 3423, 3428, 3176, 3146, 3796, 1523,
#         1800, 1960, 3393, 1411, 3419, 7944, 3860, 1467, 3344, 1517, 2480,
# ...

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
sns.barplot(x='Year',y='Hourly or Event Rate', data =airport_data, ax=ax1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Hourly or Event Rate'>

# %%
#getting the max by the hourly rate
airport_max= airport_data.groupby('Year')[['Hourly or Event Rate']].max()
airport_max
# Out:
#       Hourly or Event Rate
# Year
# 2013                131.97
# 2014                135.61
# 2015                158.04

# %%
airport_max_hrly = airport_data.loc[(airport_data['Hourly or Event Rate']== 131.97)|(airport_data['Hourly or Event Rate']== 135.61)|(airport_data['Hourly or Event Rate']== 158.04)]
airport_max_hrly
# Out:
#       Row ID  Year Department Title  Payroll Department Record Number  \
# 161    57430  2014  Airports (LAWA)               101.0    2525431620
# 283       48  2013  Airports (LAWA)               101.0    2525431620
# 9449  114540  2015  Airports (LAWA)               101.0    3303590766
#
#                          Job Class Title Employment Type  \
# 161   Assistant General Manager Airports       Full Time
# 283   Assistant General Manager Airports       Full Time
# 9449            General Manager Airports       Full Time
#
#       Hourly or Event Rate  Projected Annual Salary  Q1 Payments  Q2 Payments  \
# 161                 135.61                283153.68     63345.60     73903.20
# 283                 131.97                275553.36     59738.58     70996.38
# 9449                158.04                329987.52         0.00         0.00
#
#       Q3 Payments  Q4 Payments  Payments Over Base Pay  % Over Base Pay  \
# ...

# %%
#plotting the hrly rate by job class 
fig2, ax1 = plt.subplots(figsize = (13,5))
sns.barplot(x='Year',y='Hourly or Event Rate', data =airport_max_hrly, hue= 'Job Class Title',ax=ax1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Hourly or Event Rate'>

# %%
#getting the % change by the average hourly rate by year - Department 
airport_avg= airport_data.groupby('Year')['Hourly or Event Rate'].mean()
airport_avg= pd.DataFrame(airport_avg)

airport_avg['% increase'] = airport_avg.pct_change()*100
airport_avg['% increase']=airport_avg['% increase'].fillna(0)
airport_avg.reset_index(drop=False, inplace=True)
airport_avg
#for index, row in airport_avg.iterrows():
# Out:
#    Year  Hourly or Event Rate  % increase
# 0  2013             35.195285    0.000000
# 1  2014             36.343200    3.261557
# 2  2015             36.437126    0.258443

# %%
# % of the avg hourly change over time 
airport_avg.plot.bar(x='Year',y='% increase')
plt.show()
#sns.barplot(x='Year',y='% increase', data =airport_avg, ax=ax1)

# %%
#getting the min by the hourly rate
airport_min= airport_data.groupby('Year')[['Hourly or Event Rate']].min()
airport_min
# Out:
#       Hourly or Event Rate
# Year
# 2013                 13.31
# 2014                 13.31
# 2015                 14.05

# %%
airport_min_hrly = airport_data.loc[(airport_data['Hourly or Event Rate']== 13.31)|(airport_data['Hourly or Event Rate']==13.31 )|(airport_data['Hourly or Event Rate']==14.05 )]
airport_min_hrly
# Out:
#         Row ID  Year Department Title  Payroll Department Record Number  \
# 149286   60736  2014  Airports (LAWA)               101.0    2145485481
# 171531  117814  2015  Airports (LAWA)               101.0    1409151502
# 175958    3526  2013  Airports (LAWA)               101.0    2025213404
# 184530    3576  2013  Airports (LAWA)               101.0    1532556761
# 195477  118051  2015  Airports (LAWA)               101.0     347875308
# 195478  118050  2015  Airports (LAWA)               101.0    3602056644
# 195907  118056  2015  Airports (LAWA)               101.0    3606159235
# 195908  118055  2015  Airports (LAWA)               101.0    1259710983
# 196375  118061  2015  Airports (LAWA)               101.0    3351969437
# 198055  118077  2015  Airports (LAWA)               101.0    4134691727
# 198662  118085  2015  Airports (LAWA)               101.0    2143519165
# 199682  118097  2015  Airports (LAWA)               101.0    2791432451
# ...

# %%
fig1, ax1 = plt.subplots(figsize = (13,5))
sns.barplot(x='Job Class Title',y='Hourly or Event Rate', data =job_class_not,hue='Year',ax=ax1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c9f417d19541> in <module>
#       1 fig1, ax1 = plt.subplots(figsize = (13,5))
# ----> 2 sns.barplot(x='Job Class Title',y='Hourly or Event Rate', data =job_class_not,hue='Year',ax=ax1)
#
# NameError: name 'job_class_not' is not defined

# %%
airport_min= airport_data[['Hourly or Event Rate', 'Year','Job Class Title']].groupby('Year').min()
airport_min = airport_min.loc[(airport_min['Department Title'])
airport_min

# %%
#getting the avg of the total payments vs projected payments.
airport_mean= airport_data.groupby('Year')[['Projected Annual Salary', 'Total Payments']].mean()
airport_mean= pd.DataFrame(airport_mean)
airport_mean
# Out:
#       Projected Annual Salary  Total Payments
# Year
# 2013             73487.103834    77640.654920
# 2014             75884.677231    81332.354689
# 2015             76080.541720    81124.121349

# %%
#
airport_max_salary= airport_data.groupby('Year')[['Projected Annual Salary', 'Total Payments']].max()
airport_max_salary= pd.DataFrame(airport_max_salary)
airport_max_salary
# Out:
#       Projected Annual Salary  Total Payments
# Year
# 2013                275553.36       267828.56
# 2014                283153.68       277992.00
# 2015                329987.52       293525.60

# %%
true_payment= []
for index,row in airport_max_salary.iterrows():
    salary = airport_data.loc[airport_data['Projected Annual Salary']=row]
    true_payment.append(salary)  
true_payment
# Out:
#   File "<ipython-input-17-ceaf9c7aae3f>", line 3
#     salary = airport_data.loc[airport_data['Projected Annual Salary']=row]
#                                                                      ^
# SyntaxError: invalid syntax

# %%
airport_max_salary = airport_data.loc[(airport_data['Projected Annual Salary']==275553.36 )|(airport_data['Projected Annual Salary']==283153.68 )|(airport_data['Projected Annual Salary']==329987.52)]
airport_max_salary
# Out:
#       Row ID  Year Department Title  Payroll Department Record Number  \
# 161    57430  2014  Airports (LAWA)               101.0    2525431620
# 283       48  2013  Airports (LAWA)               101.0    2525431620
# 9449  114540  2015  Airports (LAWA)               101.0    3303590766
#
#                          Job Class Title Employment Type  \
# 161   Assistant General Manager Airports       Full Time
# 283   Assistant General Manager Airports       Full Time
# 9449            General Manager Airports       Full Time
#
#       Hourly or Event Rate  Projected Annual Salary  Q1 Payments  Q2 Payments  \
# 161                 135.61                283153.68     63345.60     73903.20
# 283                 131.97                275553.36     59738.58     70996.38
# 9449                158.04                329987.52         0.00         0.00
#
#       Q3 Payments  Q4 Payments  Payments Over Base Pay  % Over Base Pay  \
# ...

# %%
airport_max_salary = airport_data.loc[(airport_data['Projected Annual Salary']==275553.36 )|(airport_data['Projected Annual Salary']==283153.68 )|(airport_data['Projected Annual Salary']==329987.52)]
airport_max_salary=airport_max_salary[['Year','Projected Annual Salary','Total Payments','Q1 Payments','Q2 Payments','Q3 Payments','Q4 Payments','Job Class Title' ]]
airport_max_salary.set_index('Year', inplace=True)
airport_max_salary
# Out:
#       Projected Annual Salary  Total Payments  Q1 Payments  Q2 Payments  \
# Year
# 2014                283153.68       277992.00     63345.60     73903.20
# 2013                275553.36       267828.56     59738.58     70996.38
# 2015                329987.52       156575.20         0.00         0.00
#
#       Q3 Payments  Q4 Payments                     Job Class Title
# Year
# 2014      64801.6      75941.6  Assistant General Manager Airports
# 2013      63190.4      73903.2  Assistant General Manager Airports
# 2015      79216.0      77359.2            General Manager Airports

# %%
airport_max_salary.plot.bar(rot =0)
plt.show()
