# %%
import pandas as pd
pd.set_option('display.max_columns',None, 'display.max_rows', None)

# %%
salary_data = pd.read_csv('Resources/City_PayRoll_LA.csv', low_memory=False)
salary_data.head()
# Out:
#    Row ID  Year           Department Title  Payroll Department Record Number  \
# 0  111391  2014      Water And Power (DWP)                 NaN    1412316577
# 1   31732  2013              Police (LAPD)              4301.0     432728338
# 2   27697  2013              Police (LAPD)              4301.0      97182506
# 3   14136  2013        Harbor (Port of LA)              3201.0     950136941
# 4   91896  2014  Public Works - Sanitation              7024.0    3230003445
#
#                      Job Class Title Employment Type Hourly or Event Rate  \
# 0  Commercial Service Representative       Full Time                  NaN
# 1                   Police Officer I       Full Time               $25.12
# 2                  Police Officer II       Full Time               $42.77
# 3            Senior Security Officer       Full Time               $28.75
# 4                Senior Clerk Typist       Full Time               $30.92
#
#   Projected Annual Salary Q1 Payments Q2 Payments Q3 Payments Q4 Payments  \
# 0               $70386.48   $16129.89   $17829.78   $17678.24   $22946.57
# 1               $52450.56   $11331.00   $13859.93   $11968.32   $14048.20
# 2               $89303.76   $20036.32   $23479.20   $21153.60   $24360.49
# 3               $60028.96   $15793.88   $18560.38   $16471.18   $21110.80
# 4               $64553.13   $14700.00   $17313.10   $15257.17   $17313.10
#
#   Payments Over Base Pay % Over Base Pay Total Payments   Base Pay  \
# 0              $14273.91          23.67%      $74584.48  $60310.57
# 1               $1700.40           3.43%      $51207.45  $49507.05
# 2               $4120.20           4.85%      $89029.61  $84909.41
# 3              $14275.44          24.76%      $71936.24  $57660.80
# 4               $5191.62           8.74%      $64583.37  $59391.75
#
#   Permanent Bonus Pay Longevity Bonus Pay Temporary Bonus Pay Lump Sum Pay  \
# 0               $0.00               $0.00               $0.00          NaN
# 1            $1269.83               $0.00             $239.20        $0.00
# 2            $1954.51               $0.00            $1519.00        $0.00
# 3               $0.00            $1585.72             $935.00        $0.00
# 4               $0.00            $4774.25               $0.00        $0.00
#
#   Overtime Pay Other Pay & Adjustments Other Pay (Payroll Explorer)  MOU  \
# 0      $369.12               $13904.79                    $13904.79  NaN
# 1       $11.13                 $180.24                     $1689.27   24
# 2      $482.29                 $164.40                     $3637.91   24
# 3    $11504.72                 $250.00                     $2770.72   12
# 4      $417.37                   $0.00                     $4774.25   03
#
#               MOU Title  FMS Department  Job Class Pay Grade  \
# 0                   NaN              98       1230       NaN
# 1  POLICE OFFICERS UNIT              70       2214         A
# 2  POLICE OFFICERS UNIT              70       2214         2
# 3      SUPV BLUE COLLAR              42       3184         0
# 4         CLERICAL UNIT              82       1368         0
#
#   Average Health Cost Average Dental Cost Average Basic Life  \
# 0           $16842.08            $1282.61              $0.00
# 1           $11651.40             $898.08            $191.04
# 2           $11651.40             $898.08            $191.04
# 3           $10710.24             $405.24             $11.40
# 4           $11000.40             $409.68             $11.40
#
#   Average Benefit Cost Benefits Plan                           Job Class Link
# 0            $18124.69           DWP  http://per.lacity.org/perspecs/1230.pdf
# 1            $12740.52        Police  http://per.lacity.org/perspecs/2214.pdf
# 2            $12740.52        Police  http://per.lacity.org/perspecs/2214.pdf
# 3            $11126.88          City  http://per.lacity.org/perspecs/3184.pdf
# 4            $11421.48          City  http://per.lacity.org/perspecs/1368.pdf

# %%
salary_data.dropna(subset=['Total Payments'], inplace=True)
columns_replace = [ 'Hourly or Event Rate', 'Projected Annual Salary', 'Q1 Payments',
       'Q2 Payments', 'Q3 Payments', 'Q4 Payments', 'Payments Over Base Pay',
        'Total Payments', 'Base Pay', 'Permanent Bonus Pay',
       'Longevity Bonus Pay', 'Temporary Bonus Pay', 'Lump Sum Pay',
       'Overtime Pay', 'Other Pay & Adjustments',
       'Other Pay (Payroll Explorer)', 'Average Health Cost', 'Average Dental Cost',
       'Average Basic Life', 'Average Benefit Cost']


for col in columns_replace:
    salary_data[col]=salary_data[col].str.replace('$','').astype(float)

# %%
# salary_data.columns
salary_data.head()
len(salary_data)
# Out:
# 285008

# %%
salary_data['% Over Base Pay']=salary_data['% Over Base Pay'].str.replace('%','')
salary_data.head()
# Out:
#    Row ID  Year           Department Title  Payroll Department Record Number  \
# 0  111391  2014      Water And Power (DWP)                 NaN    1412316577
# 1   31732  2013              Police (LAPD)              4301.0     432728338
# 2   27697  2013              Police (LAPD)              4301.0      97182506
# 3   14136  2013        Harbor (Port of LA)              3201.0     950136941
# 4   91896  2014  Public Works - Sanitation              7024.0    3230003445
#
#                      Job Class Title Employment Type  Hourly or Event Rate  \
# 0  Commercial Service Representative       Full Time                   NaN
# 1                   Police Officer I       Full Time                 25.12
# 2                  Police Officer II       Full Time                 42.77
# 3            Senior Security Officer       Full Time                 28.75
# 4                Senior Clerk Typist       Full Time                 30.92
#
#    Projected Annual Salary  Q1 Payments  Q2 Payments  Q3 Payments  \
# 0                 70386.48     16129.89     17829.78     17678.24
# 1                 52450.56     11331.00     13859.93     11968.32
# 2                 89303.76     20036.32     23479.20     21153.60
# 3                 60028.96     15793.88     18560.38     16471.18
# 4                 64553.13     14700.00     17313.10     15257.17
#
#    Q4 Payments  Payments Over Base Pay % Over Base Pay  Total Payments  \
# 0     22946.57                14273.91           23.67        74584.48
# 1     14048.20                 1700.40            3.43        51207.45
# 2     24360.49                 4120.20            4.85        89029.61
# 3     21110.80                14275.44           24.76        71936.24
# 4     17313.10                 5191.62            8.74        64583.37
#
#    Base Pay  Permanent Bonus Pay  Longevity Bonus Pay  Temporary Bonus Pay  \
# 0  60310.57                 0.00                 0.00                  0.0
# 1  49507.05              1269.83                 0.00                239.2
# 2  84909.41              1954.51                 0.00               1519.0
# 3  57660.80                 0.00              1585.72                935.0
# 4  59391.75                 0.00              4774.25                  0.0
#
#    Lump Sum Pay  Overtime Pay  Other Pay & Adjustments  \
# 0           NaN        369.12                 13904.79
# 1           0.0         11.13                   180.24
# 2           0.0        482.29                   164.40
# 3           0.0      11504.72                   250.00
# 4           0.0        417.37                     0.00
#
#    Other Pay (Payroll Explorer)  MOU             MOU Title  FMS Department  \
# 0                      13904.79  NaN                   NaN              98
# 1                       1689.27   24  POLICE OFFICERS UNIT              70
# 2                       3637.91   24  POLICE OFFICERS UNIT              70
# 3                       2770.72   12      SUPV BLUE COLLAR              42
# 4                       4774.25   03         CLERICAL UNIT              82
#
#    Job Class Pay Grade  Average Health Cost  Average Dental Cost  \
# 0       1230       NaN             16842.08              1282.61
# 1       2214         A             11651.40               898.08
# 2       2214         2             11651.40               898.08
# 3       3184         0             10710.24               405.24
# 4       1368         0             11000.40               409.68
#
#    Average Basic Life  Average Benefit Cost Benefits Plan  \
# 0                0.00              18124.69           DWP
# 1              191.04              12740.52        Police
# 2              191.04              12740.52        Police
# 3               11.40              11126.88          City
# 4               11.40              11421.48          City
#
#                             Job Class Link
# 0  http://per.lacity.org/perspecs/1230.pdf
# 1  http://per.lacity.org/perspecs/2214.pdf
# 2  http://per.lacity.org/perspecs/2214.pdf
# 3  http://per.lacity.org/perspecs/3184.pdf
# 4  http://per.lacity.org/perspecs/1368.pdf

# %%
cols = salary_data.columns[9:17]
cols
# Out:
# Index(['Q1 Payments', 'Q2 Payments', 'Q3 Payments', 'Q4 Payments',
#        'Payments Over Base Pay', '% Over Base Pay', 'Total Payments',
#        'Base Pay'],
#       dtype='object')

# %%
import numpy as np
salary_data = salary_data.replace(0,np.nan).dropna(axis=0, how='all')
salary_data.dropna(subset=cols, inplace=True)
salary_data.head()
# cleaned_csv = salary_data.to_csv('Output/Final_Cleaned.csv', index=False)
# Out:
#    Row ID  Year           Department Title  Payroll Department Record Number  \
# 0  111391  2014      Water And Power (DWP)                 NaN    1412316577
# 1   31732  2013              Police (LAPD)              4301.0     432728338
# 2   27697  2013              Police (LAPD)              4301.0      97182506
# 3   14136  2013        Harbor (Port of LA)              3201.0     950136941
# 4   91896  2014  Public Works - Sanitation              7024.0    3230003445
#
#                      Job Class Title Employment Type  Hourly or Event Rate  \
# 0  Commercial Service Representative       Full Time                   NaN
# 1                   Police Officer I       Full Time                 25.12
# 2                  Police Officer II       Full Time                 42.77
# 3            Senior Security Officer       Full Time                 28.75
# 4                Senior Clerk Typist       Full Time                 30.92
#
#    Projected Annual Salary  Q1 Payments  Q2 Payments  Q3 Payments  \
# 0                 70386.48     16129.89     17829.78     17678.24
# 1                 52450.56     11331.00     13859.93     11968.32
# 2                 89303.76     20036.32     23479.20     21153.60
# 3                 60028.96     15793.88     18560.38     16471.18
# 4                 64553.13     14700.00     17313.10     15257.17
#
#    Q4 Payments  Payments Over Base Pay % Over Base Pay  Total Payments  \
# 0     22946.57                14273.91           23.67        74584.48
# 1     14048.20                 1700.40            3.43        51207.45
# 2     24360.49                 4120.20            4.85        89029.61
# 3     21110.80                14275.44           24.76        71936.24
# 4     17313.10                 5191.62            8.74        64583.37
#
#    Base Pay  Permanent Bonus Pay  Longevity Bonus Pay  Temporary Bonus Pay  \
# 0  60310.57                  NaN                  NaN                  NaN
# 1  49507.05              1269.83                  NaN                239.2
# 2  84909.41              1954.51                  NaN               1519.0
# 3  57660.80                  NaN              1585.72                935.0
# 4  59391.75                  NaN              4774.25                  NaN
#
#    Lump Sum Pay  Overtime Pay  Other Pay & Adjustments  \
# 0           NaN        369.12                 13904.79
# 1           NaN         11.13                   180.24
# 2           NaN        482.29                   164.40
# 3           NaN      11504.72                   250.00
# 4           NaN        417.37                      NaN
#
#    Other Pay (Payroll Explorer)  MOU             MOU Title  FMS Department  \
# 0                      13904.79  NaN                   NaN              98
# 1                       1689.27   24  POLICE OFFICERS UNIT              70
# 2                       3637.91   24  POLICE OFFICERS UNIT              70
# 3                       2770.72   12      SUPV BLUE COLLAR              42
# 4                       4774.25   03         CLERICAL UNIT              82
#
#    Job Class Pay Grade  Average Health Cost  Average Dental Cost  \
# 0       1230       NaN             16842.08              1282.61
# 1       2214         A             11651.40               898.08
# 2       2214         2             11651.40               898.08
# 3       3184         0             10710.24               405.24
# 4       1368         0             11000.40               409.68
#
#    Average Basic Life  Average Benefit Cost Benefits Plan  \
# 0                 NaN              18124.69           DWP
# 1              191.04              12740.52        Police
# 2              191.04              12740.52        Police
# 3               11.40              11126.88          City
# 4               11.40              11421.48          City
#
#                             Job Class Link
# 0  http://per.lacity.org/perspecs/1230.pdf
# 1  http://per.lacity.org/perspecs/2214.pdf
# 2  http://per.lacity.org/perspecs/2214.pdf
# 3  http://per.lacity.org/perspecs/3184.pdf
# 4  http://per.lacity.org/perspecs/1368.pdf

# %%
salary_data['Department Title'].nunique()
# Out:
# 58

# %%
salary_data['Department Title'].value_counts()
# Out:
# Police (LAPD)                                                   36922
# Water And Power (DWP)                                           27464
# Recreation And Parks                                            11974
# Fire (LAFD)                                                     10185
# Airports (LAWA)                                                  9391
# Public Works - Sanitation                                        6812
# Transportation (LADOT)                                           4929
# General Services                                                 3965
# Library                                                          3015
# Harbor (Port of LA)                                              2524
# Public Works - Street Services                                   2484
# Building and Safety                                              2236
# City Attorney                                                    2056
# Public Works - Engineering                                       1691
# Housing And Community Investment Department                      1468
# Personnel                                                        1240
# Information Technology Agency                                    1237
# Animal Services                                                   898
# Office of Finance                                                 880
# Public Works - Contract Administration                            800
# Zoo                                                               750
# Public Works - Street Lighting                                    522
# City Planning                                                     426
# Controller                                                        366
# Economic And Workforce Development Department (EWDD)              357
# City Employees Retirement System (LACERS)                         320
# City Clerk                                                        283
# City Administrative Officer (CAO)                                 270
# Pension (LAFPP)                                                   268
# Mayor                                                             241
# City Planning And Development (DCP)                               231
# Public Works - Board of Public Works                              227
# Los Angeles Convention Center                                     212
# Cultural Affairs                                                  179
# Office of the Chief Legislative Analyst (CLA)                     109
# Aging                                                              88
# El Pueblo De Los Angeles Historical Monument Authority             72
# Emergency Management                                               60
# Neighborhood Empowerment (DONE)                                    53
# City Ethics Commission                                             43
# Council District 12 (CD 12)                                        36
# Council District 04 (CD 4)                                         36
# Council District 11 (CD 11)                                        36
# Council District 02 (CD 2)                                         33
# Council District 13 (CD 13)                                        32
# Council District 15 (CD 15)                                        31
# Disability                                                         30
# Council District 14 (CD 14)                                        30
# Council District 05 (CD 5)                                         29
# Council District 08 (CD 8)                                         27
# Council District 10 (CD 10)                                        27
# Council District 09 (CD 9)                                         25
# Council District 07 (CD 7)                                         22
# Council District 03 (CD 3)                                         22
# Council District 01 (CD 1)                                         18
# Los Angeles Department of Convention and Tourism Development       18
# Council District 06 (CD 6)                                         17
# Employee Relations Board                                            6
# Name: Department Title, dtype: int64

# %%
group_salary = salary_data.groupby('Department Title').nunique()
select_data = group_salary[group_salary['Total Payments']>10000]
select_index = select_data.index
group_salary.sort_values('Total Payments', ascending = False)
select_data
select_index
# Out:
# Index(['Fire (LAFD)', 'Police (LAPD)', 'Recreation And Parks',
#        'Water And Power (DWP)'],
#       dtype='object', name='Department Title')

# %%
dataset = salary_data.loc[salary_data['Department Title'].isin(select_index)].copy(deep=True)
dataset = dataset.sort_values('Total Payments', ascending = False)
dataset.head()
# Out:
#         Row ID  Year       Department Title  Payroll Department Record Number  \
# 168006  123010  2015            Fire (LAFD)              3001.0    1081092723
# 142297  162626  2015  Water And Power (DWP)                 NaN    2720285819
# 155335  123011  2015            Fire (LAFD)              3001.0    2236794545
# 119602  123012  2015            Fire (LAFD)              3001.0    2837442648
# 46520   103240  2014  Water And Power (DWP)                 NaN    3314958958
#
#                    Job Class Title Employment Type  Hourly or Event Rate  \
# 168006              Fire Captain I       Full Time                 63.51
# 142297  Electrical Service Manager       Full Time                123.12
# 155335              Fire Captain I       Full Time                 63.39
# 119602             Firefighter III       Full Time                 39.64
# 46520    Power Engineering Manager       Full Time                   NaN
#
#         Projected Annual Salary  Q1 Payments  Q2 Payments  Q3 Payments  \
# 168006                132603.66     95633.26    107862.25    122415.22
# 142297                257074.56     78928.80     58554.62    156964.90
# 155335                132347.88     87225.34     92065.04    127257.45
# 119602                 82766.83     74708.81    105354.78    117150.25
# 46520                 258494.40     67843.00     78582.83     67931.00
#
#         Q4 Payments  Payments Over Base Pay % Over Base Pay  Total Payments  \
# 168006    122683.60               327765.53          271.26       448594.33
# 142297    130418.51               294852.11          226.78       424866.83
# 155335     98818.97               284538.00          235.49       405366.80
# 119602    107094.21               317149.65          363.88       404308.05
# 46520     188913.96               181955.59           82.22       403270.79
#
#          Base Pay  Permanent Bonus Pay  Longevity Bonus Pay  \
# 168006  120828.80               9967.6                  NaN
# 142297  130014.72                  NaN                  NaN
# 155335  120828.80               9690.4                  NaN
# 119602   87158.40              19752.4               7410.0
# 46520   221315.20               1284.8                  NaN
#
#         Temporary Bonus Pay  Lump Sum Pay  Overtime Pay  \
# 168006               1088.0       2137.63     311315.62
# 142297                  NaN           NaN           NaN
# 155335               1088.0           NaN     273495.60
# 119602               1088.0           NaN     286732.56
# 46520                   NaN           NaN           NaN
#
#         Other Pay & Adjustments  Other Pay (Payroll Explorer)  MOU  \
# 168006                  3256.68                      16449.91   23
# 142297                294852.11                     294852.11    M
# 155335                   264.00                      11042.40   23
# 119602                  2166.69                      30417.09   23
# 46520                 180670.79                     181955.59  NaN
#
#                            MOU Title  FMS Department  Job Class Pay Grade  \
# 168006  FIREFIGHTERS & FIRE CAPTAINS              38       2142         1
# 142297     MANAGEMENT EMPLOYEES UNIT              98       5265       NaN
# 155335  FIREFIGHTERS & FIRE CAPTAINS              38       2142         1
# 119602  FIREFIGHTERS & FIRE CAPTAINS              38       2112         3
# 46520                            NaN              98       9453       NaN
#
#         Average Health Cost  Average Dental Cost  Average Basic Life  \
# 168006             13031.40               896.76              178.68
# 142297             17486.94              1268.69                 NaN
# 155335             13031.40               896.76              178.68
# 119602             13031.40               896.76              178.68
# 46520              16842.08              1282.61                 NaN
#
#         Average Benefit Cost Benefits Plan  \
# 168006              14106.84          Fire
# 142297              18755.63           DWP
# 155335              14106.84          Fire
# 119602              14106.84          Fire
# 46520               18124.69           DWP
#
#                                  Job Class Link
# 168006  http://per.lacity.org/perspecs/2142.pdf
# 142297  http://per.lacity.org/perspecs/5265.pdf
# 155335  http://per.lacity.org/perspecs/2142.pdf
# 119602  http://per.lacity.org/perspecs/2112.pdf
# 46520   http://per.lacity.org/perspecs/9453.pdf

# %%
dataset['Department Title'].unique()
# Out:
# array(['Fire (LAFD)', 'Water And Power (DWP)', 'Police (LAPD)',
#        'Recreation And Parks'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (13,5))
# sns.stripplot(x='Department Title',y='Total Payments', data = dataset, alpha = 0.2, ax = ax,hue ='Year')
sns.boxplot(x='Department Title',y='Total Payments', data = dataset, ax = ax, showmeans=True)
# Out:
# <AxesSubplot:xlabel='Department Title', ylabel='Total Payments'>

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.violinplot(x='Department Title',y='Total Payments', data = dataset, ax = ax, showmeans=True)
# Out:
# <AxesSubplot:xlabel='Department Title', ylabel='Total Payments'>

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.violinplot(x='Department Title',y='Base Pay', data = dataset, ax = ax, showmeans=True)
# Out:
# <AxesSubplot:xlabel='Department Title', ylabel='Base Pay'>

# %%
fig, ax = plt.subplots(figsize = (13,5))
# sns.stripplot(x='Department Title',y='Total Payments', data = dataset, alpha = 0.2, ax = ax,hue ='Year')
sns.boxplot(x='Department Title',y='Base Pay', data = dataset, ax = ax, showmeans=True)
# Out:
# <AxesSubplot:xlabel='Department Title', ylabel='Base Pay'>

# %%
water_df = dataset.loc[(dataset['Department Title']=='Water And Power (DWP)') & (dataset['Job Class Title']=='Commercial Service Representative')]
# fig, ax = plt.subplots(figsize = (13,5))
sns.histplot(data=water_df, x='Total Payments', hue='Year', element='step').set_title('Histogram of Total Payments of Police')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Payments of Police')

# %%
water_jt_csr = dataset.loc[(dataset['Department Title']=='Water And Power (DWP)') & (dataset['Job Class Title']=='Commercial Service Representative')]
water_jt_csr.head()
# fig, ax = plt.subplots(figsize = (13,5))
sns.stripplot(data=water_jt_csr, y='Total Payments', x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Payments'>

# %%
sns.stripplot(data=water_jt_csr, y='Base Pay', x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Base Pay'>

# %%
# sns.set_palette(sns.color_palette("Paired"))
sns.boxplot(data=water_jt_csr, y='Total Payments', x='Year', showmeans=True)
plt.title('Customer Service Representative from Water_Power Dept Total Pay by Year')
plt.show()

# %%
sns.boxplot(data=water_jt_csr, y='Base Pay', x='Year', showmeans=True)
plt.title('Customer Service Representative from Water_Power Dept Base Pay by Year')
plt.show()

# %%
tips = sns.load_dataset("tips")
fig, ax = plt.subplots(figsize=(15,8))
dd=pd.melt(water_jt_csr,id_vars=['Year'],value_vars=['Total Payments', 'Base Pay', 'Average Benefit Cost'],var_name='test')
sns.violinplot(x='Year',y='value',data=dd,hue='test', showmeans=True)
plt.grid(which='both')
plt.legend(loc='best')
# ax.axhline(y=70000, color ='r',linestyle=':')
# ax.axhline(y=79000, color ='r',linestyle=':')
ax.tick_params(rotation=0)

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.violinplot(x="Year", y="Total Payments", data=water_jt_csr, color="0.8")
sns.stripplot(x="Year", y="Total Payments", data=water_jt_csr, jitter=True, zorder=1)
plt.grid(which='both')

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.violinplot(x="Year", y="Base Pay", data=water_jt_csr, color="0.8")
sns.stripplot(x="Year", y="Base Pay", data=water_jt_csr, jitter=True, zorder=1)
plt.grid(which='both')

# %%
# fig, ax = plt.subplots(figsize=(10,5))
# # dd=pd.melt(water_jt_csr,id_vars=['Year'],value_vars=['Total Payments', 'Base Pay', 'Average Benefit Cost'],var_name='test')
# sns.violinplot(x='Year',y='value',data=dd,hue='test', showmeans=True)
# # plt.grid(which='both')
# plt.legend(loc='best')
# ax.tick_params(rotation=0)

counts = water_jt_csr['Year'].value_counts()
counts_df = pd.DataFrame(counts)
counts_df.reset_index(inplace=True)
counts_df
# Out:
#    index  Year
# 0   2015   590
# 1   2013   559
# 2   2014   556

# %%
sns.barplot(x='index',y='Year', data=counts_df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='Year'>

# %%
water_2013 = dataset.loc[(dataset['Department Title']=='Water And Power (DWP)') & (dataset['Year']==2013) & (dataset['Job Class Title']=='Commercial Service Representative')]
# fig, ax = plt.subplots(figsize = (13,5))
sns.histplot(data=water_2013, x='Total Payments', hue='Year', element='step').set_title('Histogram of Total Payments in 2013')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Payments in 2013')

# %%
water_2014 = dataset.loc[(dataset['Department Title']=='Water And Power (DWP)') & (dataset['Year']==2014) & (dataset['Job Class Title']=='Commercial Service Representative')]
# fig, ax = plt.subplots(figsize = (13,5))
sns.histplot(data=water_2014, x='Total Payments', hue='Year', element='step').set_title('Histogram of Total Payments in 2014')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Payments in 2014')

# %%
water_2015 = dataset.loc[(dataset['Department Title']=='Water And Power (DWP)') & (dataset['Year']==2015) & (dataset['Job Class Title']=='Commercial Service Representative')]
# fig, ax = plt.subplots(figsize = (13,5))
sns.histplot(data=water_2015, x='Total Payments', hue='Year', element='step').set_title('Histogram of Total Payments in 2015')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Payments in 2015')

# %%
grouped_df = dataset.groupby(['Department Title'])
grouped_df['Job Class Title'].nunique()
# Out:
# Department Title
# Fire (LAFD)              115
# Police (LAPD)            188
# Recreation And Parks     194
# Water And Power (DWP)    341
# Name: Job Class Title, dtype: int64

# %%
import numpy as np
wp_df = dataset[(dataset['Department Title']=='Water And Power (DWP)')]
wp_df.head()

# fig, ax = plt.subplots(figsize=(18,5))
# sns.histplot(data=wp_df, x='Job Class Title')
# ax.tick_params(rotation=90)
# Out:
#         Row ID  Year       Department Title  Payroll Department Record Number  \
# 142297  162626  2015  Water And Power (DWP)                 NaN    2720285819
# 46520   103240  2014  Water And Power (DWP)                 NaN    3314958958
# 158047  162627  2015  Water And Power (DWP)                 NaN    2973354356
# 97399   103241  2014  Water And Power (DWP)                 NaN    2973354356
# 157748  162628  2015  Water And Power (DWP)                 NaN    3707730741
#
#                                         Job Class Title Employment Type  \
# 142297                       Electrical Service Manager       Full Time
# 46520                         Power Engineering Manager       Full Time
# 158047      Electrical Distribution Mechanic Supervisor       Full Time
# 97399       Electrical Distribution Mechanic Supervisor       Full Time
# 157748  Transmission & Distribution District Supervisor       Full Time
#
#         Hourly or Event Rate  Projected Annual Salary  Q1 Payments  \
# 142297                123.12                257074.56     78928.80
# 46520                    NaN                258494.40     67843.00
# 158047                 72.73                151860.24     90521.02
# 97399                    NaN                151860.24     80191.36
# 157748                 89.34                186541.92     86893.12
#
#         Q2 Payments  Q3 Payments  Q4 Payments  Payments Over Base Pay  \
# 142297     58554.62    156964.90    130418.51               294852.11
# 46520      78582.83     67931.00    188913.96               181955.59
# 158047     73177.18    121420.58    109430.61               288242.48
# 97399      91868.20    112020.87     92235.16               270518.32
# 157748     74427.28     82595.09    126293.38               184381.67
#
#        % Over Base Pay  Total Payments   Base Pay  Permanent Bonus Pay  \
# 142297          226.78       424866.83  130014.72                  NaN
# 46520            82.22       403270.79  221315.20              1284.80
# 158047          271.14       394549.39  106306.91             16635.42
# 97399           255.69       376315.59  105797.27             17033.59
# 157748           99.22       370208.87  185827.20                  NaN
#
#         Longevity Bonus Pay  Temporary Bonus Pay  Lump Sum Pay  Overtime Pay  \
# 142297                  NaN                  NaN           NaN           NaN
# 46520                   NaN                  NaN           NaN           NaN
# 158047             15977.21                  NaN           NaN     191697.49
# 97399              16311.10                  NaN           NaN     199385.01
# 157748                  NaN                  NaN           NaN      93271.04
#
#         Other Pay & Adjustments  Other Pay (Payroll Explorer)  MOU  \
# 142297                294852.11                     294852.11    M
# 46520                 180670.79                     181955.59  NaN
# 158047                 63932.36                      96544.99    B
# 97399                  37788.62                      71133.31  NaN
# 157748                 91110.63                      91110.63    M
#
#                            MOU Title  FMS Department  Job Class Pay Grade  \
# 142297     MANAGEMENT EMPLOYEES UNIT              98       5265       NaN
# 46520                            NaN              98       9453       NaN
# 158047  SUPERVISORY BLUE COLLAR UNIT              98       3873       NaN
# 97399                            NaN              98       3873       NaN
# 157748     MANAGEMENT EMPLOYEES UNIT              98       3875       NaN
#
#         Average Health Cost  Average Dental Cost  Average Basic Life  \
# 142297             17486.94              1268.69                 NaN
# 46520              16842.08              1282.61                 NaN
# 158047             17486.94              1268.69                 NaN
# 97399              16842.08              1282.61                 NaN
# 157748             17486.94              1268.69                 NaN
#
#         Average Benefit Cost Benefits Plan  \
# 142297              18755.63           DWP
# 46520               18124.69           DWP
# 158047              18755.63           DWP
# 97399               18124.69           DWP
# 157748              18755.63           DWP
#
#                                  Job Class Link
# 142297  http://per.lacity.org/perspecs/5265.pdf
# 46520   http://per.lacity.org/perspecs/9453.pdf
# 158047  http://per.lacity.org/perspecs/3873.pdf
# 97399   http://per.lacity.org/perspecs/3873.pdf
# 157748  http://per.lacity.org/perspecs/3875.pdf

# %%
# fig, ax = plt.subplots(figsize=(18,5))
# sns.countplot(x='Job Class Title', data=wp_df, order=wp_df['Job Class Title'].value_counts().index)
# ax.tick_params(rotation=90)

# %%
wp_count = wp_df['Job Class Title'].value_counts()
# wp_count

# %%
len(wp_df)
# Out:
# 27464

# %%
job_titles = wp_count[wp_count>1000].index
job_titles
# Out:
# Index(['Commercial Service Representative', 'Electric Distribution Mechanic',
#        'Senior Clerk Typist', 'Electrical Engineering Associate'],
#       dtype='object')

# %%
#filtering fire_df for interested job titles
wp_df_final = wp_df[wp_df['Job Class Title'].isin(job_titles)].copy(deep=True)
wp_df_final.head()
# Out:
#         Row ID  Year       Department Title  Payroll Department Record Number  \
# 60159    46770  2013  Water And Power (DWP)                 NaN      93717895
# 101643   46771  2013  Water And Power (DWP)                 NaN     687873419
# 162191  162659  2015  Water And Power (DWP)                 NaN      93717895
# 164041  162663  2015  Water And Power (DWP)                 NaN    1462455289
# 161000  162667  2015  Water And Power (DWP)                 NaN    1689127711
#
#                          Job Class Title Employment Type  \
# 60159   Electrical Engineering Associate       Full Time
# 101643    Electric Distribution Mechanic       Full Time
# 162191  Electrical Engineering Associate       Full Time
# 164041    Electric Distribution Mechanic       Full Time
# 161000    Electric Distribution Mechanic       Full Time
#
#         Hourly or Event Rate  Projected Annual Salary  Q1 Payments  \
# 60159                    NaN                133130.88     53308.48
# 101643                   NaN                115236.72     58517.27
# 162191                 63.76                133130.88     86387.68
# 164041                 57.77                120623.76     84864.99
# 161000                 56.36                117679.68     71843.73
#
#         Q2 Payments  Q3 Payments  Q4 Payments  Payments Over Base Pay  \
# 60159      87022.97     74614.80     88694.49               172122.99
# 101643     80591.60     76839.22     84119.74               190784.63
# 162191     75393.12     68111.59     59908.39               158187.39
# 164041     60422.58     76609.06     65137.86               173204.60
# 161000     66220.00     75958.39     71950.04               177861.70
#
#        % Over Base Pay  Total Payments   Base Pay  Permanent Bonus Pay  \
# 60159           130.87       303640.74  131517.75                  NaN
# 101643          174.58       300067.83  109283.20                  NaN
# 162191          120.19       289800.78  131613.39                  NaN
# 164041          152.16       287034.49  113829.89                  NaN
# 161000          164.52       285972.16  108110.46                  NaN
#
#         Longevity Bonus Pay  Temporary Bonus Pay  Lump Sum Pay  Overtime Pay  \
# 60159                   NaN                  NaN           NaN     162272.36
# 101643             13757.52                  NaN           NaN     162260.48
# 162191                  NaN                  NaN           NaN     141789.51
# 164041             12990.20                  NaN           NaN     142796.75
# 161000              6360.12                  NaN           NaN     141750.70
#
#         Other Pay & Adjustments  Other Pay (Payroll Explorer)  MOU  \
# 60159                   9850.63                       9850.63  NaN
# 101643                 14766.63                      28524.15  NaN
# 162191                 16397.88                      16397.88    3
# 164041                 17417.65                      30407.85    8
# 161000                 29750.88                      36111.00    8
#
#                                      MOU Title  FMS Department  Job Class  \
# 60159                                      NaN              98       7525
# 101643                                     NaN              98       3879
# 162191                       PROFESSIONAL UNIT              98       7525
# 164041  OPERATING MAINTENANCE AND SERVICE UNIT              98       3879
# 161000  OPERATING MAINTENANCE AND SERVICE UNIT              98       3879
#
#        Pay Grade  Average Health Cost  Average Dental Cost  \
# 60159        NaN             15860.53              1250.49
# 101643       NaN             15860.53              1250.49
# 162191       NaN             17486.94              1268.69
# 164041       NaN             17486.94              1268.69
# 161000       NaN             17486.94              1268.69
#
#         Average Basic Life  Average Benefit Cost Benefits Plan  \
# 60159                  NaN              17111.02           DWP
# 101643                 NaN              17111.02           DWP
# 162191                 NaN              18755.63           DWP
# 164041                 NaN              18755.63           DWP
# 161000                 NaN              18755.63           DWP
#
#                                  Job Class Link
# 60159   http://per.lacity.org/perspecs/7525.pdf
# 101643  http://per.lacity.org/perspecs/3879.pdf
# 162191  http://per.lacity.org/perspecs/7525.pdf
# 164041  http://per.lacity.org/perspecs/3879.pdf
# 161000  http://per.lacity.org/perspecs/3879.pdf

# %%
fig, ax = plt.subplots(figsize=(18,5))
dd=pd.melt(wp_df_final,id_vars=['Job Class Title'],value_vars=['Total Payments', 'Base Pay'],var_name='test')
sns.boxplot(x='Job Class Title',y='value',data=dd,hue='test', showmeans=True)
plt.legend(loc='upper left')
ax.tick_params(rotation=0)

# %%
fig, ax = plt.subplots(figsize=(18,5))
dd=pd.melt(wp_df_final,id_vars=['Job Class Title'],value_vars=['Total Payments', 'Base Pay'],var_name='test')
sns.violinplot(x='Job Class Title',y='value',data=dd,hue='test')
plt.legend(loc='upper left')
ax.tick_params(rotation=0)

# %%
# fig, ax = plt.subplots(figsize=(18,5))
# sns.histplot(data=wp_df_final, x='Job Class Title', hue='Year', element='bars', ).set_title('Histogram of Job Class Titles')
# ax.tick_params(rotation=90)

# %%
# sns.set_palette(sns.color_palette("Paired"))
# fig, ax = plt.subplots(figsize=(18,5))
# sns.countplot(x='Job Class Title', data=wp_df_final, order=wp_df_final['Job Class Title'].value_counts().index, hue='Year')
# ax.tick_params(rotation=0)

# %%
sns.set_palette(sns.color_palette("Paired"))
fig, ax = plt.subplots(figsize=(18,5))
sns.barplot(x='Job Class Title', data=wp_df_final, y='Base Pay', hue='Year')
ax.tick_params(rotation=0)

# %%
fig, ax = plt.subplots(figsize=(15,7))
wp_data=pd.melt(wp_df_final,id_vars=['Job Class Title'],value_vars=['Total Payments','Base Pay', 'Average Benefit Cost'],var_name='Year')
sns.set_palette(sns.color_palette("Paired"))
sns.barplot(x='Job Class Title',y='value',data=wp_data,hue='Year')
ax.tick_params(rotation=0)
plt.legend(loc='upper right')

# %%
# fig, ax = plt.subplots(figsize=(18,5))
# sns.countplot(x='Job Class Title', data=wp_df_final, order=wp_df_final['Base Pay'].value_counts().index, hue='Year')
# ax.tick_params(rotation=90)

# %%
fig, ax = plt.subplots(figsize=(18,7))
dd=pd.melt(wp_df_final,id_vars=['Job Class Title'],value_vars=['Total Payments','Base Pay', 'Average Benefit Cost'],var_name='Year')
sns.barplot(x='Job Class Title',y='value',data=dd,hue='Year')
ax.tick_params(rotation=0)
plt.legend(loc='best')

# %%
sns.set_palette(sns.color_palette("Paired"))
fig, ax = plt.subplots(figsize=(18,10))
dd=pd.melt(wp_df_final,id_vars=['Year'],value_vars=['Total Payments','Base Pay', 'Average Benefit Cost'],var_name='Job Class Title')
sns.barplot(x='Year',y='value',data=dd,hue='Job Class Title')
ax.tick_params(rotation=0)

plt.legend(loc='upper right')

# %%
fig, ax = plt.subplots(figsize=(18,6))
ax.tick_params(rotation=0)
sns.stripplot(data=wp_df_final,x='Pay Grade',y='Base Pay',hue='Job Class Title',alpha = 0.7)
plt.legend(loc='best')
# Out:
# C:\Users\sreek\anaconda3\lib\site-packages\seaborn\categorical.py:373: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   ax.set_xlim(-.5, len(self.plot_data) - .5, auto=None)

# %%
# fig,ax = plt.subplots(figsize =(10,5))
# sns.stripplot(data=wp_df_final,x='Pay Grade',y='Base Pay',hue='Job Class Title',alpha = 0.5)
# plt.xlim(-1,10)

# %%
wp_df_final.columns
wp_df_final['% Over Base Pay'] = wp_df_final['% Over Base Pay'].astype(float)
wp_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5375 entries, 60159 to 134623
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Row ID                        5375 non-null   int64
#  1   Year                          5375 non-null   int64
#  2   Department Title              5375 non-null   object
#  3   Payroll Department            0 non-null      float64
#  4   Record Number                 5375 non-null   object
#  5   Job Class Title               5375 non-null   object
#  6   Employment Type               5375 non-null   object
#  7   Hourly or Event Rate          1855 non-null   float64
#  8   Projected Annual Salary       5375 non-null   float64
#  9   Q1 Payments                   5375 non-null   float64
#  10  Q2 Payments                   5375 non-null   float64
#  11  Q3 Payments                   5375 non-null   float64
#  12  Q4 Payments                   5375 non-null   float64
#  13  Payments Over Base Pay        5375 non-null   float64
#  14  % Over Base Pay               5375 non-null   float64
#  15  Total Payments                5375 non-null   float64
#  16  Base Pay                      5375 non-null   float64
#  17  Permanent Bonus Pay           1149 non-null   float64
#  18  Longevity Bonus Pay           847 non-null    float64
#  19  Temporary Bonus Pay           0 non-null      float64
#  20  Lump Sum Pay                  3 non-null      float64
#  21  Overtime Pay                  4747 non-null   float64
#  22  Other Pay & Adjustments       5375 non-null   float64
#  23  Other Pay (Payroll Explorer)  5375 non-null   float64
#  24  MOU                           1855 non-null   object
#  25  MOU Title                     1855 non-null   object
#  26  FMS Department                5375 non-null   int64
#  27  Job Class                     5375 non-null   int64
#  28  Pay Grade                     0 non-null      object
#  29  Average Health Cost           5351 non-null   float64
#  30  Average Dental Cost           5351 non-null   float64
#  31  Average Basic Life            0 non-null      float64
#  32  Average Benefit Cost          5351 non-null   float64
#  33  Benefits Plan                 5351 non-null   object
#  34  Job Class Link                5375 non-null   object
# dtypes: float64(22), int64(4), object(9)
# memory usage: 1.6+ MB

# %%
water_df = wp_df_final.groupby(['Job Class Title', 'Year'])
water_data = water_df.mean()
water_data = water_data[['Total Payments', 'Base Pay', 'Average Benefit Cost', 'Payments Over Base Pay', '% Over Base Pay' ]]
water_data
# Out:
#                                         Total Payments       Base Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013    79185.857943   63915.847692
#                                   2014    74090.258489   61819.140036
#                                   2015    71674.257271   60432.365746
# Electric Distribution Mechanic    2013   136138.566930  100966.542154
#                                   2014   145294.207864  100250.088403
#                                   2015   150476.783502   98658.582043
# Electrical Engineering Associate  2013   135041.608928  112626.135681
#                                   2014   134910.748667  110610.399913
#                                   2015   134512.743278  108402.605758
# Senior Clerk Typist               2013    76221.443941   66864.109410
#                                   2014    76214.129220   67062.536532
#                                   2015    75765.573686   66248.221649
#
#                                         Average Benefit Cost  \
# Job Class Title                   Year
# Commercial Service Representative 2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
# Electric Distribution Mechanic    2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
# Electrical Engineering Associate  2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
# Senior Clerk Typist               2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
#
#                                         Payments Over Base Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013            15270.010250
#                                   2014            12271.118453
#                                   2015            11241.891525
# Electric Distribution Mechanic    2013            35172.024776
#                                   2014            45044.119461
#                                   2015            51818.201459
# Electrical Engineering Associate  2013            22415.473246
#                                   2014            24300.348754
#                                   2015            26110.137521
# Senior Clerk Typist               2013             9357.334531
#                                   2014             9151.592688
#                                   2015             9517.352036
#
#                                         % Over Base Pay
# Job Class Title                   Year
# Commercial Service Representative 2013        41.240340
#                                   2014        36.675306
#                                   2015        34.238237
# Electric Distribution Mechanic    2013        35.509552
#                                   2014        46.762176
#                                   2015        54.017802
# Electrical Engineering Associate  2013        19.764058
#                                   2014        23.334638
#                                   2015        23.784986
# Senior Clerk Typist               2013        17.136193
#                                   2014        19.224462
#                                   2015        20.141546

# %%
len(wp_df_final)
# Out:
# 5375

# %%
water_data['% increase Tot Pay'] = water_data['Total Payments'].groupby(level=0).pct_change()*100
water_data['% increase Base Pay'] = water_data['Base Pay'].groupby(level=0).pct_change()*100
water_data['% increase Benefits'] = water_data['Average Benefit Cost'].groupby(level=0).pct_change()*100
water_data['Cum % increase Tot Pay'] = water_data['% increase Tot Pay'].groupby(level=0).cumsum()
water_data['Cum % increase Base Pay'] = water_data['% increase Base Pay'].groupby(level=0).cumsum()
water_data['Cum % increase Benefits'] = water_data['% increase Benefits'].groupby(level=0).cumsum()
water_data
# Out:
#                                         Total Payments       Base Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013    79185.857943   63915.847692
#                                   2014    74090.258489   61819.140036
#                                   2015    71674.257271   60432.365746
# Electric Distribution Mechanic    2013   136138.566930  100966.542154
#                                   2014   145294.207864  100250.088403
#                                   2015   150476.783502   98658.582043
# Electrical Engineering Associate  2013   135041.608928  112626.135681
#                                   2014   134910.748667  110610.399913
#                                   2015   134512.743278  108402.605758
# Senior Clerk Typist               2013    76221.443941   66864.109410
#                                   2014    76214.129220   67062.536532
#                                   2015    75765.573686   66248.221649
#
#                                         Average Benefit Cost  \
# Job Class Title                   Year
# Commercial Service Representative 2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
# Electric Distribution Mechanic    2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
# Electrical Engineering Associate  2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
# Senior Clerk Typist               2013              17111.02
#                                   2014              18124.69
#                                   2015              18755.63
#
#                                         Payments Over Base Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013            15270.010250
#                                   2014            12271.118453
#                                   2015            11241.891525
# Electric Distribution Mechanic    2013            35172.024776
#                                   2014            45044.119461
#                                   2015            51818.201459
# Electrical Engineering Associate  2013            22415.473246
#                                   2014            24300.348754
#                                   2015            26110.137521
# Senior Clerk Typist               2013             9357.334531
#                                   2014             9151.592688
#                                   2015             9517.352036
#
#                                         % Over Base Pay  % increase Tot Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013        41.240340                 NaN
#                                   2014        36.675306           -6.434987
#                                   2015        34.238237           -3.260889
# Electric Distribution Mechanic    2013        35.509552                 NaN
#                                   2014        46.762176            6.725237
#                                   2015        54.017802            3.566953
# Electrical Engineering Associate  2013        19.764058                 NaN
#                                   2014        23.334638           -0.096904
#                                   2015        23.784986           -0.295014
# Senior Clerk Typist               2013        17.136193                 NaN
#                                   2014        19.224462           -0.009597
#                                   2015        20.141546           -0.588546
#
#                                         % increase Base Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013                  NaN
#                                   2014            -3.280419
#                                   2015            -2.243277
# Electric Distribution Mechanic    2013                  NaN
#                                   2014            -0.709595
#                                   2015            -1.587536
# Electrical Engineering Associate  2013                  NaN
#                                   2014            -1.789758
#                                   2015            -1.996010
# Senior Clerk Typist               2013                  NaN
#                                   2014             0.296762
#                                   2015            -1.214262
#
#                                         % increase Benefits  \
# Job Class Title                   Year
# Commercial Service Representative 2013                  NaN
#                                   2014             5.924077
#                                   2015             3.481108
# Electric Distribution Mechanic    2013                  NaN
#                                   2014             5.924077
#                                   2015             3.481108
# Electrical Engineering Associate  2013                  NaN
#                                   2014             5.924077
#                                   2015             3.481108
# Senior Clerk Typist               2013                  NaN
#                                   2014             5.924077
#                                   2015             3.481108
#
#                                         Cum % increase Tot Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013                     NaN
#                                   2014               -6.434987
#                                   2015               -9.695876
# Electric Distribution Mechanic    2013                     NaN
#                                   2014                6.725237
#                                   2015               10.292189
# Electrical Engineering Associate  2013                     NaN
#                                   2014               -0.096904
#                                   2015               -0.391918
# Senior Clerk Typist               2013                     NaN
#                                   2014               -0.009597
#                                   2015               -0.598143
#
#                                         Cum % increase Base Pay  \
# Job Class Title                   Year
# Commercial Service Representative 2013                      NaN
#                                   2014                -3.280419
#                                   2015                -5.523696
# Electric Distribution Mechanic    2013                      NaN
#                                   2014                -0.709595
#                                   2015                -2.297131
# Electrical Engineering Associate  2013                      NaN
#                                   2014                -1.789758
#                                   2015                -3.785768
# Senior Clerk Typist               2013                      NaN
#                                   2014                 0.296762
#                                   2015                -0.917500
#
#                                         Cum % increase Benefits
# Job Class Title                   Year
# Commercial Service Representative 2013                      NaN
#                                   2014                 5.924077
#                                   2015                 9.405185
# Electric Distribution Mechanic    2013                      NaN
#                                   2014                 5.924077
#                                   2015                 9.405185
# Electrical Engineering Associate  2013                      NaN
#                                   2014                 5.924077
#                                   2015                 9.405185
# Senior Clerk Typist               2013                      NaN
#                                   2014                 5.924077
#                                   2015                 9.405185

# %%
water_data=water_data.reset_index()
water_data
# Out:
#                       Job Class Title  Year  Total Payments       Base Pay  \
# 0   Commercial Service Representative  2013    79185.857943   63915.847692
# 1   Commercial Service Representative  2014    74090.258489   61819.140036
# 2   Commercial Service Representative  2015    71674.257271   60432.365746
# 3      Electric Distribution Mechanic  2013   136138.566930  100966.542154
# 4      Electric Distribution Mechanic  2014   145294.207864  100250.088403
# 5      Electric Distribution Mechanic  2015   150476.783502   98658.582043
# 6    Electrical Engineering Associate  2013   135041.608928  112626.135681
# 7    Electrical Engineering Associate  2014   134910.748667  110610.399913
# 8    Electrical Engineering Associate  2015   134512.743278  108402.605758
# 9                 Senior Clerk Typist  2013    76221.443941   66864.109410
# 10                Senior Clerk Typist  2014    76214.129220   67062.536532
# 11                Senior Clerk Typist  2015    75765.573686   66248.221649
#
#     Average Benefit Cost  Payments Over Base Pay  % Over Base Pay  \
# 0               17111.02            15270.010250        41.240340
# 1               18124.69            12271.118453        36.675306
# 2               18755.63            11241.891525        34.238237
# 3               17111.02            35172.024776        35.509552
# 4               18124.69            45044.119461        46.762176
# 5               18755.63            51818.201459        54.017802
# 6               17111.02            22415.473246        19.764058
# 7               18124.69            24300.348754        23.334638
# 8               18755.63            26110.137521        23.784986
# 9               17111.02             9357.334531        17.136193
# 10              18124.69             9151.592688        19.224462
# 11              18755.63             9517.352036        20.141546
#
#     % increase Tot Pay  % increase Base Pay  % increase Benefits  \
# 0                  NaN                  NaN                  NaN
# 1            -6.434987            -3.280419             5.924077
# 2            -3.260889            -2.243277             3.481108
# 3                  NaN                  NaN                  NaN
# 4             6.725237            -0.709595             5.924077
# 5             3.566953            -1.587536             3.481108
# 6                  NaN                  NaN                  NaN
# 7            -0.096904            -1.789758             5.924077
# 8            -0.295014            -1.996010             3.481108
# 9                  NaN                  NaN                  NaN
# 10           -0.009597             0.296762             5.924077
# 11           -0.588546            -1.214262             3.481108
#
#     Cum % increase Tot Pay  Cum % increase Base Pay  Cum % increase Benefits
# 0                      NaN                      NaN                      NaN
# 1                -6.434987                -3.280419                 5.924077
# 2                -9.695876                -5.523696                 9.405185
# 3                      NaN                      NaN                      NaN
# 4                 6.725237                -0.709595                 5.924077
# 5                10.292189                -2.297131                 9.405185
# 6                      NaN                      NaN                      NaN
# 7                -0.096904                -1.789758                 5.924077
# 8                -0.391918                -3.785768                 9.405185
# 9                      NaN                      NaN                      NaN
# 10               -0.009597                 0.296762                 5.924077
# 11               -0.598143                -0.917500                 9.405185

# %%
years = [2014, 2015]
water_data = water_data[water_data['Year'].isin(years)]

random_df = water_data[['Job Class Title', 'Year', 'Cum % increase Tot Pay', 'Cum % increase Base Pay','Cum % increase Benefits']]
random_df
random_df.to_csv('Output/Water_Power.csv')

# %%
fig, ax = plt.subplots(figsize=(18,10))
data=pd.melt(water_data,id_vars='Year',value_vars=['Cum % increase Tot Pay','Cum % increase Base Pay','Cum % increase Benefits'],var_name='test')
sns.barplot(x='Year',y='value',data=data,hue='test')
ax.tick_params(rotation=0)

# plt.legend(loc='upper left')

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
sns.barplot(x='Year',y='Base Pay', data =wp_df_final, ax=ax1, hue='Job Class Title')
plt.ylim(top=160000)
plt.legend(loc='upper right')

# %%
fig, ax1 = plt.subplots(figsize = (13,8))
sns.barplot(x='Year',y='Total Payments', data =wp_df_final, ax=ax1, hue='Job Class Title')
plt.ylim(top=210000)
plt.legend(loc='upper right')

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
sns.lineplot(x='Year',y='Total Payments', data =wp_df_final, ax=ax1, hue='Job Class Title', marker='o')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total Payments'>

# %%
# fig, ax1 = plt.subplots(figsize = (13,5))
# sns.barplot(x='Year',y='Total Payments', data =wp_df_final, ax=ax1, hue='Job Class Title')

fig, ax = plt.subplots(figsize=(18,10))
dd1=pd.melt(water_data,id_vars='Year',value_vars=['Total Payments','Base Pay'],var_name='test')
sns.barplot(x='Year',y='value',data=dd1,hue='test')
# ax.tick_params(rotation=90)
# print(dd1)
# plt.legend(loc='upper left')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='value'>
